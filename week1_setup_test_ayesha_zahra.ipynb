# %%
   import pandas as pd
   import geopandas as gpd
   from shapely.geometry import Point

   df = pd.DataFrame({
       'name': ['Islamabad', 'Lahore', 'Karachi'],
       'lat': [33.6844, 31.5497, 24.8607],
       'lon': [73.0479, 74.3436, 67.0011]
   })

   gdf = gpd.GeoDataFrame(
       df, geometry=gpd.points_from_xy(df.lon, df.lat), crs="EPSG:4326"
   )

   print(gdf)
   gdf.plot()
# Out:
#         name      lat      lon                 geometry
# 0  Islamabad  33.6844  73.0479  POINT (73.0479 33.6844)
# 1     Lahore  31.5497  74.3436  POINT (74.3436 31.5497)
# 2    Karachi  24.8607  67.0011  POINT (67.0011 24.8607)
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >
